# %%
import pandas as pd
import numpy as np

# Load the raw NHS111 dataset
file_path = "../data/raw/IUCADC-Apr23-to-Mar24-Revised.csv"

df = pd.read_csv(file_path)

print("Dataset shape:", df.shape)
print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.
# Dataset shape: (51948, 9)

# %%
# Preview the first 5 rows of the dataset
df.head()
# Out:
#           REPORTING_PERIOD ORG_CODE  \
# 0  IUCADC-MONTHLY-APR-2023      NKB
# 1  IUCADC-MONTHLY-APR-2023      NKB
# 2  IUCADC-MONTHLY-APR-2023      NKB
# 3  IUCADC-MONTHLY-APR-2023      NKB
# 4  IUCADC-MONTHLY-APR-2023      NKB
#
#                                             ORG_NAME CONTRACT_CODE  \
# 0  LONDON CENTRAL AND WEST UNSCHEDULED CARE COLLA...        111AD5
# 1  LONDON CENTRAL AND WEST UNSCHEDULED CARE COLLA...        111AD5
# 2  LONDON CENTRAL AND WEST UNSCHEDULED CARE COLLA...        111AD5
# 3  LONDON CENTRAL AND WEST UNSCHEDULED CARE COLLA...        111AD5
# 4  LONDON CENTRAL AND WEST UNSCHEDULED CARE COLLA...        111AD5
#
#           CONTRACT_NAME ITEM_NUMBER   VALUE REGION_CODE REGION_NAME
# 0  North Central London         A01  35,693         Y56      London
# 1  North Central London         A02       0         Y56      London
# 2  North Central London         A03  28,440         Y56      London
# 3  North Central London         A05     402         Y56      London
# 4  North Central London         A07   4,019         Y56      London

# %%
# Check for duplicate rows
print("Duplicate rows:", df.duplicated().sum())

# Check number of unique values in each column
print("\nUnique values by column:")
print(df.nunique())
# Out:
# Duplicate rows: 0
#
# Unique values by column:
# REPORTING_PERIOD       12
# ORG_CODE               17
# ORG_NAME               17
# CONTRACT_CODE          38
# CONTRACT_NAME          39
# ITEM_NUMBER           117
# VALUE               14559
# REGION_CODE             8
# REGION_NAME             8
# dtype: int64

# %%
# Check dataset structure, column types and missing values
print("Dataset information:")
df.info()

print("\nMissing values by column:")
print(df.isnull().sum())
# Out:
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 51948 entries, 0 to 51947
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   REPORTING_PERIOD  51948 non-null  str
#  1   ORG_CODE          51948 non-null  str
#  2   ORG_NAME          51948 non-null  str
#  3   CONTRACT_CODE     51948 non-null  str
#  4   CONTRACT_NAME     51948 non-null  str
#  5   ITEM_NUMBER       51948 non-null  str
#  6   VALUE             51948 non-null  str
#  7   REGION_CODE       51948 non-null  str
#  8   REGION_NAME       51948 non-null  str
# dtypes: str(9)
# memory usage: 3.6 MB
#
# Missing values by column:
# REPORTING_PERIOD    0
# ORG_CODE            0
# ORG_NAME            0
# CONTRACT_CODE       0
# CONTRACT_NAME       0
# ITEM_NUMBER         0
# VALUE               0
# REGION_CODE         0
# REGION_NAME         0
# dtype: int64
